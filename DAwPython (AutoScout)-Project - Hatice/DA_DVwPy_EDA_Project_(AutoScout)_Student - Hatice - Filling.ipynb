# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">DA & DVwPY</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Exploratory Data Analysis (EDA) Project</p>
#
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">AutoScout Car Price Prediction EDA</p>

# %% [markdown]
# ## Introduction
# Welcome to "***AutoScout Exploratory Data Analysis (EDA) Project***". This is the project of completing ***Data Analysis & Data Visualization*** Courses and a successful hand-over is mandatory for getting certification for both courses. **Auto Scout** data used in this project scraped from the Website of an online car trading company in 2022, and contains many features of 13 different car makes including 594 models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using a variety of Python libraries, such as Numpy, Pandas, Matplotlib, Seaborn, Scipy, and then you will get a clean dataset for your analysis and pretictive modelling in Machine Learning Path. So you will have the chance to use all the skills you have already learned in the Data Analysis and Visualization courses.
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to ``'Data Cleaning'``. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to ``'Filling Data'``, in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation, Encoding, is done as well.
# * **The third part** is related to ``'Handling Outliers of Data'`` via Visualization libraries. So, some insights will be extracted.
#
# **``SPECIAL NOTE:``**  However, you are ``free to create your own style``. You do ``NOT`` have to stick to the steps above. Nevertheless, we, the DA & DV instructors, recommend you study each part separately to create a source notebook for your further studies.
#
# In order to build your Portfolio in terms of the GitHub account, you need to push your solution file up to your own repository.
#
# Please after solving the task, commit your notebook to GitHub and submit its link to LMS page where the project is settled down.
#
# **BE NOTED:** Please ``DO NOT FORGET`` to click the submit button.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)

# %% [markdown]
# # PART- 2 `( Handling With Missing Vales )`

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from scipy import stats

pd.options.display.max_rows = 1000
pd.options.display.max_columns = 150

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %%
df = pd.read_csv("clean_scout.csv")

# %%
df.isnull().sum()
# Out:
# make_model                  0
# price                       0
# body_type                   0
# type                        0
# doors                     359
# warranty                15165
# mileage                     1
# first_registration          2
# gearbox                   248
# fuel_type                1787
# seller                      0
# seats                    3125
# power                     572
# engine_size              1403
# gears                    9676
# co2_emissions           10036
# drivetrain              11737
# cylinders                9778
# comfort_convenience      3197
# entertainment_media      4986
# safety_security          3215
# extras                   5150
# full_service_history    16065
# upholstery              10020
# previous_owner          14615
# co2_efficiency          20826
# avg_consumption          8530
# city_consumption         8530
# country_consumption      8530
# age                         2
# dtype: int64

# %%
df.isnull().sum()*100 / df.shape[0] 
## percentage of null values
# Out:
# make_model               0.000000
# price                    0.000000
# body_type                0.000000
# type                     0.000000
# doors                    1.253929
# warranty                52.968914
# mileage                  0.003493
# first_registration       0.006986
# gearbox                  0.866224
# fuel_type                6.241705
# seller                   0.000000
# seats                   10.915124
# power                    1.997904
# engine_size              4.900454
# gears                   33.796717
# co2_emissions           35.054139
# drivetrain              40.995459
# cylinders               34.152986
# comfort_convenience     11.166608
# entertainment_media     17.415299
# safety_security         11.229480
# extras                  17.988124
# full_service_history    56.112469
# upholstery              34.998254
# previous_owner          51.047852
# co2_efficiency          72.741879
# avg_consumption         29.793922
# ...

# %%
def information(col):
    print("column name    : ", col)
    print("--------------------------------")
    print("per_of_nulls   : ", "%", round(df[col].isnull().sum()*100 / df.shape[0], 2))
    print("num_of_nulls   : ", df[col].isnull().sum())
    print("num_of_uniques : ", df[col].nunique())
    print("--------------------------------")
    print(df[col].value_counts(dropna = False))

# %% [markdown]
# ### Doors

# %%
information("doors")
# Out:
# column name    :  doors
# --------------------------------
# per_of_nulls   :  % 1.25
# num_of_nulls   :  359
# num_of_uniques :  6
# --------------------------------
# 5.0    17481
# 2.0     5523
# 4.0     3001
# 3.0     2259
# NaN      359
# 6.0        5
# 1.0        2
# Name: doors, dtype: int64

# %%
df.doors = df["doors"].fillna(df["doors"].mode()[0])

# %%
df.doors.value_counts(dropna = False)
# Out:
# 5.0    17840
# 2.0     5523
# 4.0     3001
# 3.0     2259
# 6.0        5
# 1.0        2
# Name: doors, dtype: int64

# %% [markdown]
# ### Warranty

# %%
information("warranty")
# Out:
# column name    :  warranty
# --------------------------------
# per_of_nulls   :  % 52.97
# num_of_nulls   :  15165
# num_of_uniques :  60
# --------------------------------
# NaN     15165
# 12.0     9546
# 24.0     1515
# 60.0      968
# 6.0       398
# 36.0      257
# 3.0       185
# 0.0       133
# 48.0       78
# 84.0       47
# 72.0       40
# 13.0       22
# 8.0        19
# 1.0        15
# 18.0       15
# 14.0       14
# 15.0       13
# 16.0       13
# 30.0       12
# 34.0       11
# 33.0       11
# 21.0       11
# 19.0        9
# 17.0        9
# 20.0        9
# 32.0        9
# 23.0        9
# 35.0        8
# 28.0        8
# 50.0        6
# 22.0        6
# 42.0        5
# 11.0        5
# 52.0        4
# 26.0        4
# 47.0        4
# 31.0        4
# 9.0         4
# 25.0        3
# 58.0        3
# 27.0        3
# 45.0        2
# 7.0         2
# 29.0        2
# 51.0        2
# 57.0        2
# 10.0        2
# 53.0        2
# 2.0         2
# 80.0        2
# 90.0        2
# ...

# %%
df.groupby(['make_model', 'age'])["warranty"].describe()
# Out:
#                    count  mean  std   min   25%   50%   75%   max
# make_model   age
# Dacia        0.0     0.0   NaN  NaN   NaN   NaN   NaN   NaN   NaN
#              1.0     0.0   NaN  NaN   NaN   NaN   NaN   NaN   NaN
#              47.0    0.0   NaN  NaN   NaN   NaN   NaN   NaN   NaN
# Dacia Break  0.0     1.0  12.0  NaN  12.0  12.0  12.0  12.0  12.0
# Dacia Dokker 0.0     1.0  24.0  NaN  24.0  24.0  24.0  24.0  24.0
# ...                  ...   ...  ...   ...   ...   ...   ...   ...
# Volvo XC90   10.0    2.0  12.0  0.0  12.0  12.0  12.0  12.0  12.0
#              14.0    0.0   NaN  NaN   NaN   NaN   NaN   NaN   NaN
#              15.0    0.0   NaN  NaN   NaN   NaN   NaN   NaN   NaN
#              16.0    0.0   NaN  NaN   NaN   NaN   NaN   NaN   NaN
#              18.0    2.0  12.0  0.0  12.0  12.0  12.0  12.0  12.0
#
# [3372 rows x 8 columns]

# %%
df.drop("warranty", axis = 1, inplace = True)

# %% [markdown]
# I asked ChatGPT for warranty conditions in Europe.It said that :
# "The warranty conditions for vehicles sold in Europe may vary depending on the automaker and the specific model. .The length of the warranty varies by manufacturer, but it typically covers the vehicle for at least three years or up to a certain mileage, such as 100,000 kilometers. Some automakers offer longer warranties or extended warranty options for an additional fee.The warranty usually covers defects in materials or workmanship, and may also cover certain components and systems, such as the engine, transmission, and electronics. The warranty may also include roadside assistance and other benefits."
# There are too many NaN and  and meaningless values. I don't think these values can be filled in appropriate ways. So i dropped this column.

# %% [markdown]
# ### Mileage

# %%
information("mileage")
# Out:
# column name    :  mileage
# --------------------------------
# per_of_nulls   :  % 0.0
# num_of_nulls   :  1
# num_of_uniques :  14183
# --------------------------------
# 10.0        586
# 1.0         172
# 50.0        133
# 100.0       119
# 5000.0      118
#            ...
# 141589.0      1
# 59821.0       1
# 123500.0      1
# 29781.0       1
# 230047.0      1
# Name: mileage, Length: 14184, dtype: int64

# %%
df.loc[df.mileage.isnull()]
# Out:
#       make_model    price           body_type             type  doors  \
# 10753  Fiat 500X  41570.0   Off-Road/Pick-up    Demonstration     5.0
#
#        mileage  first_registration    gearbox fuel_type  seller  seats  power  \
# 10753      NaN              2022.0  Automatic       NaN  Dealer    5.0  131.0
#
#        engine_size  gears co2_emissions drivetrain  cylinders  \
# 10753       1469.0    7.0           NaN        NaN        4.0
#
#                                      comfort_convenience  \
# 10753  Air conditioning, Armrest, Automatic climate c...
#
#                       entertainment_media  \
# 10753  Android Auto, Apple CarPlay, Radio
#
#                                          safety_security  \
# 10753  ABS, Central door lock, Central door lock with...
#
#                                                   extras full_service_history  \
# 10753  Alloy wheels, Electronic parking brake, Emerge...                  NaN
#
# ...

# %%
df.loc[(df.make_model == "Fiat 500X") & (df.age == 0) & (df.price > 30000)].sort_values(by = ["price"], ascending=False)
# Out:
#       make_model    price           body_type              type  doors  \
# 10753  Fiat 500X  41570.0   Off-Road/Pick-up     Demonstration     5.0
# 11085  Fiat 500X  38240.0      Station wagon              Used     5.0
# 10702  Fiat 500X  34990.0   Off-Road/Pick-up    Pre-registered     5.0
# 10063  Fiat 500X  32900.0        Convertible    Pre-registered     5.0
# 10076  Fiat 500X  32690.0        Convertible    Pre-registered     5.0
# 10816  Fiat 500X  32679.0   Off-Road/Pick-up    Pre-registered     5.0
# 11150  Fiat 500X  32499.0      Station wagon              Used     5.0
# 11086  Fiat 500X  31999.0      Station wagon              Used     5.0
# 10783  Fiat 500X  31899.0   Off-Road/Pick-up    Pre-registered     5.0
# 9911   Fiat 500X  31500.0        Convertible    Pre-registered     5.0
# 11196  Fiat 500X  31499.0      Station wagon              Used     5.0
#
#        mileage  first_registration    gearbox fuel_type  seller  seats  power  \
# ...

# %%
df.groupby("age")["mileage"].mean()
# Out:
# age
# -180.0     20926.000000
# -3.0       59629.000000
# -1.0      147985.000000
#  0.0        3043.333874
#  1.0       15009.230314
#  2.0       30711.259604
#  3.0       50955.461685
#  4.0       70204.331615
#  5.0       77484.786480
#  6.0       83995.415882
#  7.0       98250.392078
#  8.0      108883.928419
#  9.0      116788.029872
#  10.0     123027.413740
#  11.0     134643.419003
#  12.0     147977.105546
#  13.0     149548.219340
#  14.0     158996.961451
#  15.0     163675.329268
#  16.0     154184.002532
#  17.0     160294.968641
#  18.0     174932.939271
#  19.0     156258.805687
#  20.0     154393.181818
#  21.0     166095.005236
#  22.0     148224.406250
#  23.0     158723.423611
#  24.0     130119.142857
#  25.0     154737.320988
#  26.0     140526.281690
#  27.0     138833.974359
#  28.0     145438.037500
#  29.0     150443.563636
#  30.0     135084.500000
#  31.0     150345.129032
#  32.0     146269.592593
#  33.0     104872.600000
#  34.0     139495.545455
# ...

# %%
df.mileage = df["mileage"].fillna(1.0)

# %%
df.mileage.value_counts(dropna = False)
# Out:
# 10.0        586
# 1.0         173
# 50.0        133
# 100.0       119
# 5000.0      118
#            ...
# 141589.0      1
# 59821.0       1
# 123500.0      1
# 29781.0       1
# 230047.0      1
# Name: mileage, Length: 14183, dtype: int64

# %%
df.mileage.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### First Registration

# %%
information("first_registration")
# Out:
# column name    :  first_registration
# --------------------------------
# per_of_nulls   :  % 0.01
# num_of_nulls   :  2
# num_of_uniques :  83
# --------------------------------
# 2019.0    3667
# 2018.0    3492
# 2022.0    3086
# 2021.0    2870
# 2020.0    2473
# 2017.0    2426
# 2016.0    1486
# 2015.0    1237
# 2014.0     936
# 2013.0     703
# 2012.0     655
# 2011.0     642
# 2010.0     559
# 2007.0     492
# 2008.0     441
# 2009.0     424
# 2006.0     395
# 2005.0     287
# 2004.0     247
# 2003.0     211
# 2001.0     191
# 2002.0     187
# 2000.0     160
# 1999.0     144
# 1998.0      91
# 1997.0      81
# 1994.0      80
# 1995.0      78
# 1996.0      71
# 1991.0      62
# 1992.0      60
# 1993.0      55
# 1990.0      54
# 1966.0      41
# 1967.0      34
# 1988.0      33
# 1965.0      32
# 1973.0      29
# 1972.0      29
# 1968.0      27
# 1987.0      26
# 1978.0      23
# 1986.0      22
# 1989.0      20
# 1970.0      19
# 1971.0      18
# 1985.0      18
# 1969.0      17
# ...

# %%
df.loc[df.first_registration.isnull()]
# Out:
#                    make_model     price      body_type             type  \
# 683    Mercedes-Benz E 53 AMG  108900.0   Convertible    Demonstration
# 16884          Toyota Corolla   33999.0       Compact    Demonstration
#
#        doors  mileage  first_registration    gearbox fuel_type  seller  seats  \
# 683      2.0   3856.0                 NaN  Automatic   Benzine  Dealer    4.0
# 16884    5.0   2494.0                 NaN  Automatic   Benzine  Dealer    NaN
#
#        power  engine_size  gears co2_emissions drivetrain  cylinders  \
# 683    435.0       2999.0    8.0          219         4WD        NaN
# 16884  184.0       1987.0    NaN           89         NaN        4.0
#
#                                      comfort_convenience  \
# 683    360° camera, Air conditioning, Automatic clima...
# 16884  Air conditioning, Armrest, Automatic climate c...
#
#                                      entertainment_media  \
# 683    Android Auto, Apple CarPlay, Bluetooth, CD pla...
# ...

# %%
df.loc[(df.make_model == "Mercedes-Benz E 53 AMG") & (df.mileage <= 3856.0)]
# Out:
#                   make_model     price        body_type             type  \
# 683   Mercedes-Benz E 53 AMG  108900.0     Convertible    Demonstration
# 883   Mercedes-Benz E 53 AMG   95500.0           Coupe    Demonstration
# 1804  Mercedes-Benz E 53 AMG   88755.0   Station wagon    Demonstration
# 2116  Mercedes-Benz E 53 AMG  109989.0           Sedan    Demonstration
#
#       doors  mileage  first_registration    gearbox fuel_type  seller  seats  \
# 683     2.0   3856.0                 NaN  Automatic   Benzine  Dealer    4.0
# 883     2.0   3023.0              2022.0  Automatic   Benzine  Dealer    4.0
# 1804    5.0   3079.0              2022.0  Automatic   Benzine  Dealer    5.0
# 2116    4.0   3000.0              2022.0  Automatic   Benzine  Dealer    5.0
#
#       power  engine_size  gears co2_emissions drivetrain  cylinders  \
# 683   435.0       2999.0    8.0          219         4WD        NaN
# 883   435.0       2999.0    9.0          214         4WD        6.0
# ...

# %%
df.loc[(df.make_model == "Toyota Corolla") & (df.mileage <= 2494.0)]
# Out:
#            make_model    price        body_type              type  doors  \
# 16884  Toyota Corolla  33999.0         Compact     Demonstration     5.0
# 17994  Toyota Corolla  31490.0   Station wagon    Pre-registered     5.0
# 18010  Toyota Corolla  39480.0   Station wagon    Employee's car     5.0
# 18026  Toyota Corolla  24600.0   Station wagon    Pre-registered     5.0
# 18059  Toyota Corolla  31998.0   Station wagon              Used     5.0
# 18060  Toyota Corolla  32990.0   Station wagon    Pre-registered     5.0
# 18069  Toyota Corolla  43950.0   Station wagon              Used     5.0
# 18074  Toyota Corolla  31900.0   Station wagon    Pre-registered     5.0
# 18089  Toyota Corolla  31190.0   Station wagon    Pre-registered     5.0
# 18101  Toyota Corolla  36390.0   Station wagon    Pre-registered     5.0
# 18107  Toyota Corolla  34990.0   Station wagon    Pre-registered     5.0
# 18140  Toyota Corolla  40899.0   Station wagon              Used     5.0
# ...

# %%
df.first_registration = df["first_registration"].fillna(2022.0)

# %%
df.first_registration.isnull().sum()
# Out:
# 0

# %%
 def filling_mode(df, group_col1, group_col2, col_name):
    
    for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                mode1 = list(df[cond1][col_name].mode())
                mode2 = list(df[cond2][col_name].mode())
                if mode2 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].mode()[0])
                elif mode1 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond1][col_name].mode()[0])
                else:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[col_name].mode()[0])

# %% [markdown]
# ### Gearbox

# %%
information("gearbox")
# Out:
# column name    :  gearbox
# --------------------------------
# per_of_nulls   :  % 0.87
# num_of_nulls   :  248
# num_of_uniques :  3
# --------------------------------
# Manual            17023
# Automatic         11287
# NaN                 248
# Semi-automatic       72
# Name: gearbox, dtype: int64

# %%
df.loc[df.gearbox.isnull()]
# Out:
#                     make_model     price           body_type  \
# 150        Mercedes-Benz A 180   31450.0            Compact
# 175     Mercedes-Benz A 35 AMG   52999.0            Compact
# 210        Mercedes-Benz A 200   21999.0            Compact
# 222        Mercedes-Benz A 220   22999.0            Compact
# 235        Mercedes-Benz A 220   31999.0            Compact
# 239           Mercedes-Benz CL   39999.0            Compact
# 241        Mercedes-Benz A 200   29999.0            Compact
# 244        Mercedes-Benz A 200   20999.0            Compact
# 246           Mercedes-Benz CL   27499.0            Compact
# 247     Mercedes-Benz A 35 AMG   47999.0            Compact
# 256        Mercedes-Benz A 180   19999.0            Compact
# 258           Mercedes-Benz CL   29999.0            Compact
# 259        Mercedes-Benz A 220   29999.0            Compact
# 267        Mercedes-Benz A 220   29999.0            Compact
# 268        Mercedes-Benz A 180   20999.0            Compact
# ...

# %%
filling_mode(df, "make_model", "body_type", "gearbox")

# %%
df.gearbox.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Fuel Type

# %%
information("fuel_type")
# Out:
# column name    :  fuel_type
# --------------------------------
# per_of_nulls   :  % 6.24
# num_of_nulls   :  1787
# num_of_uniques :  5
# --------------------------------
# Benzine    17333
# Diesel      8727
# NaN         1787
# LPG/CNG      379
# Others       216
# Hybrit       188
# Name: fuel_type, dtype: int64

# %%
filling_mode(df, "make_model", "body_type", "fuel_type")

# %%
df.fuel_type.isnull().sum()
# Out:
# 0

# %%
df.fuel_type.value_counts()
# Out:
# Benzine    18387
# Diesel      9150
# Hybrit       440
# LPG/CNG      386
# Others       267
# Name: fuel_type, dtype: int64

# %% [markdown]
# ## Seats

# %%
information("seats")
# Out:
# column name    :  seats
# --------------------------------
# per_of_nulls   :  % 10.92
# num_of_nulls   :  3125
# num_of_uniques :  11
# --------------------------------
# 5.0     18308
# 4.0      5390
# NaN      3125
# 2.0      1186
# 7.0       488
# 8.0        43
# 9.0        35
# 3.0        25
# 6.0        12
# 0.0         9
# 1.0         7
# 17.0        2
# Name: seats, dtype: int64

# %%
filling_mode(df, "make_model", "body_type", "seats")

# %%
df.seats.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Power

# %%
information("power")
# Out:
# column name    :  power
# --------------------------------
# per_of_nulls   :  % 2.0
# num_of_nulls   :  572
# num_of_uniques :  351
# --------------------------------
# 150.0     1992
# 131.0     1356
# 120.0     1182
# 110.0     1166
# 90.0      1110
# 140.0     1033
# 116.0     1002
# 101.0      892
# 190.0      787
# 69.0       701
# 95.0       685
# 136.0      681
# NaN        572
# 75.0       515
# 125.0      477
# 200.0      458
# 170.0      422
# 163.0      418
# 109.0      349
# 179.0      339
# 122.0      318
# 184.0      296
# 235.0      249
# 160.0      247
# 156.0      246
# 177.0      241
# 114.0      240
# 105.0      236
# 300.0      234
# 204.0      232
# 280.0      224
# 91.0       213
# 111.0      204
# 86.0       200
# 197.0      199
# 132.0      185
# 72.0       176
# 141.0      163
# 392.0      155
# 80.0       149
# 194.0      143
# 99.0       139
# 250.0      138
# 165.0      134
# 60.0       133
# 82.0       133
# 245.0      130
# 224.0      130
# ...

# %%
filling_mode(df, "make_model", "body_type", "power")

# %%
df.power.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Engine Size

# %%
information("engine_size")
# Out:
# column name    :  engine_size
# --------------------------------
# per_of_nulls   :  % 4.9
# num_of_nulls   :  1403
# num_of_uniques :  467
# --------------------------------
# 1598.0     2099
# 999.0      2068
# 1969.0     1929
# NaN        1403
# 1461.0     1110
# 1998.0     1000
# 998.0       925
# 1199.0      867
# 1498.0      782
# 1997.0      665
# 1968.0      625
# 1984.0      580
# 1332.0      510
# 1798.0      473
# 1560.0      472
# 898.0       405
# 1499.0      397
# 1197.0      382
# 1242.0      373
# 1995.0      352
# 1991.0      351
# 1368.0      348
# 1248.0      322
# 2435.0      302
# 1600.0      252
# 2143.0      242
# 1364.0      226
# 1500.0      210
# 5038.0      204
# 3982.0      203
# 1950.0      202
# 1591.0      201
# 1956.0      195
# 2000.0      191
# 3498.0      175
# 1395.0      174
# 1987.0      159
# 1149.0      157
# 1796.0      156
# 3696.0      154
# 1200.0      153
# 1490.0      152
# 1198.0      149
# 1497.0      149
# 2400.0      148
# ...

# %%
filling_mode(df, "make_model", "body_type", "engine_size")
##When I try to fill it according to the power properties, it gets harder to work.
## filling_mode(df, "make_model", " power", "engine_size")

# %%
df.engine_size.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Gears

# %%
information("gears")
# Out:
# column name    :  gears
# --------------------------------
# per_of_nulls   :  % 33.8
# num_of_nulls   :  9676
# num_of_uniques :  11
# --------------------------------
# NaN     9676
# 6.0     8412
# 5.0     5335
# 7.0     1738
# 8.0     1690
# 1.0      712
# 9.0      642
# 4.0      256
# 10.0     112
# 0.0       31
# 3.0       24
# 2.0        2
# Name: gears, dtype: int64

# %%
filling_mode(df, "make_model", "gearbox", "gears")

# %%
df.gears.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Co2 Emissions

# %%
information("co2_emissions")
# Out:
# column name    :  co2_emissions
# --------------------------------
# per_of_nulls   :  % 35.05
# num_of_nulls   :  10036
# num_of_uniques :  347
# --------------------------------
# NaN        10036
# 0           1038
# 119          393
# 124          340
# 129          319
# 114          313
# 99           312
# 115          304
# 139          298
# 109          265
# 108          262
# 125          255
# 149          255
# 123          230
# 138          230
# 130          227
# 120          218
# 117          214
# 110          213
# 127          211
# 126          204
# 111          204
# 104          197
# 112          186
# 95           183
# 107          179
# 135          178
# 116          175
# 154          173
# 134          171
# 145          170
# 122          169
# 133          165
# 178          164
# 113          161
# 106          158
# 128          158
# 103          157
# 121          157
# 131          153
# 93           147
# 98           144
# 105          141
# ...

# %%
df.loc[df.fuel_type == "Benzine", "co2_emissions"] = df.loc[df.fuel_type == "Benzine", "co2_emissions"].fillna(df.loc[df.fuel_type == "Benzine", "co2_emissions"].mode()[0])
df.loc[df.fuel_type == "Benzine", "co2_emissions"]
# Out:
# 2          0
# 3          0
# 5        196
# 7          0
# 8        168
#          ...
# 28620      0
# 28624      0
# 28626    217
# 28628    149
# 28629    251
# Name: co2_emissions, Length: 18387, dtype: object

# %%
df.loc[df.fuel_type == "Diesel", "co2_emissions"] = df.loc[df.fuel_type == "Diesel", "co2_emissions"].fillna(df.loc[df.fuel_type == "Diesel", "co2_emissions"].mode()[0])
df.loc[df.fuel_type == "Diesel", "co2_emissions"]
# Out:
# 0         0
# 4         0
# 6         0
# 9         0
# 10       98
#         ...
# 28621     0
# 28622     0
# 28623    94
# 28625     0
# 28627    99
# Name: co2_emissions, Length: 9150, dtype: object

# %%
df.loc[df.fuel_type == "LPG/CNG", "co2_emissions"] = df.loc[df.fuel_type == "LPG/CNG", "co2_emissions"].fillna(df.loc[df.fuel_type == "LPG/CNG", "co2_emissions"].mode()[0])
df.loc[df.fuel_type == "LPG/CNG", "co2_emissions"]
# Out:
# 88         96
# 277        99
# 413       214
# 741       222
# 1319      327
# 2705       93
# 3137      168
# 3140       0
# 3251      160
# 3284       96
# 3306       96
# 3418       96
# 3419       96
# 3524      128
# 3939      121
# 4329      133
# 4335      132
# 4495       96
# 4569      129
# 4879       96
# 4992     100
# 5030       96
# 5302      139
# 5363      196
# 5417     196
# 5523       96
# 5532       96
# 5619       98
# 5663      178
# 6040      131
# 6187      118
# 6234      118
# 6243      131
# 6253      118
# 6261      118
# 6331       96
# 6770      106
# 6773      106
# 6790      106
# 6800      106
# 6868       96
# 6908      106
# 7006       94
# 7011       96
# 7019       94
# 7023       94
# 7026      106
# 7027       94
# 7037       94
# 7040       94
# 7095       94
# 7097      106
# 7112       94
# 7133      109
# 7560      159
# 7795      178
# 8301        7
# 8309       96
# 8827      169
# 8832      178
# 8977      129
# 9056       30
# ...

# %%
df.loc[df.fuel_type == "Others", "co2_emissions"] = df.loc[df.fuel_type == "Others", "co2_emissions"].fillna(df.loc[df.fuel_type == "Others", "co2_emissions"].mode()[0])
df.loc[df.fuel_type == "Others", "co2_emissions"]
# Out:
# 884      144
# 1015     144
# 1791     144
# 2061     144
# 2292     144
# 3247     144
# 3513     138
# 4230     144
# 4433     144
# 5133      98
# 5152      28
# 5568     175
# 5655     144
# 6172     144
# 6181     144
# 6182     144
# 6183     144
# 6218     135
# 6271     144
# 6741     144
# 7048     144
# 8033     139
# 8451     144
# 8997      25
# 9015      31
# 9093      31
# 9094      25
# 9095      31
# 9108     144
# 9167     144
# 9447      38
# 9484      28
# 9886     108
# 9888     108
# 10132    114
# 10934    144
# 10944    144
# 10957    144
# 11085    134
# 11086    133
# 11104    133
# 11196    133
# 11458    144
# 11568    117
# 13172     96
# 13360    144
# 13414    125
# 13519    113
# 14467    144
# 16942    144
# 17567     86
# 17588    144
# 17629    144
# 17690    144
# 17696    144
# 17700    144
# 17726    144
# 17748    144
# 17756    144
# 17757    144
# 17800    144
# 17802    144
# 17810    144
# 17814    144
# 17823    144
# 17824    144
# ...

# %%
df.loc[df.fuel_type == "Hybrit", "co2_emissions"] = df.loc[df.fuel_type == "Hybrit", "co2_emissions"].fillna(df.loc[df.fuel_type == "Hybrit", "co2_emissions"].mode()[0])
df.loc[df.fuel_type == "Hybrit", "co2_emissions"]
# Out:
# 1          0
# 93         0
# 94         0
# 108        0
# 1213       0
# 1226       0
# 1271       0
# 1273       0
# 1281       0
# 1283       0
# 1303       0
# 1304       0
# 1307       0
# 1326       0
# 1331       0
# 1341       0
# 1350       0
# 1361       0
# 1364       0
# 1369       0
# 1400       0
# 1416       0
# 1425       0
# 1427       0
# 1436       0
# 1447       0
# 1458       0
# 1513       0
# 1575       0
# 1628       0
# 1641       0
# 1777       0
# 1798       0
# 1998       0
# 2000       0
# 2004       0
# 2015       0
# 2045       0
# 2082       0
# 2084       0
# 2086       0
# 2099       0
# 2130       0
# 2144       0
# 2156       0
# 2161       0
# 2166       0
# 2182       0
# 2192       0
# 2199       0
# 2230       0
# 2246       0
# 2255       0
# 2272       0
# 2276       0
# 2278       0
# 2301       0
# 2312       0
# 2317       0
# 2322       0
# 2328       0
# 2331       0
# 2355       0
# 2356       0
# 2360       0
# 2372       0
# ...

# %%
df.co2_emissions.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Drivetrain

# %%
information("drivetrain")
# Out:
# column name    :  drivetrain
# --------------------------------
# per_of_nulls   :  % 41.0
# num_of_nulls   :  11737
# num_of_uniques :  3
# --------------------------------
# Front    12066
# NaN      11737
# 4WD       3252
# Rear      1575
# Name: drivetrain, dtype: int64

# %%
filling_mode(df, "make_model", "body_type", "drivetrain")

# %%
df.drivetrain.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Cylinders

# %%
information("cylinders")
# Out:
# column name    :  cylinders
# --------------------------------
# per_of_nulls   :  % 34.15
# num_of_nulls   :  9778
# num_of_uniques :  12
# --------------------------------
# 4.0     13068
# NaN      9778
# 3.0      3258
# 6.0      1013
# 5.0       799
# 8.0       539
# 2.0       103
# 0.0        35
# 1.0        21
# 12.0        8
# 7.0         6
# 26.0        1
# 16.0        1
# Name: cylinders, dtype: int64

# %%
## filling_mode(df, "make_model", "engine_size", "cylinders")
filling_mode(df, "make_model", "body_type", "cylinders")
##When I try to fill it according to the engine_size properties, it gets harder to work.

# %%
df.cylinders.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Comfort Convenience

# %%
information("comfort_convenience")
# Out:
# column name    :  comfort_convenience
# --------------------------------
# per_of_nulls   :  % 11.17
# num_of_nulls   :  3197
# num_of_uniques :  14438
# --------------------------------
# NaN                                                                                                                                                                                                                                                                                                                                                                                                            3197
# ...

# %%
filling_mode(df, "make_model", "body_type", "comfort_convenience")

# %%
df.comfort_convenience.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# make_model                  0
# price                       0
# body_type                   0
# type                        0
# doors                       0
# mileage                     0
# first_registration          0
# gearbox                     0
# fuel_type                   0
# seller                      0
# seats                       0
# power                       0
# engine_size                 0
# gears                       0
# co2_emissions               0
# drivetrain                  0
# cylinders                   0
# comfort_convenience         0
# entertainment_media      4986
# safety_security          3215
# extras                   5150
# full_service_history    16065
# upholstery              10020
# previous_owner          14615
# co2_efficiency          20826
# avg_consumption          8530
# city_consumption         8530
# country_consumption      8530
# age                         2
# dtype: int64

# %% [markdown]
# ## Entertainment Media

# %%
information("entertainment_media")
# Out:
# column name    :  entertainment_media
# --------------------------------
# per_of_nulls   :  % 17.42
# num_of_nulls   :  4986
# num_of_uniques :  1944
# --------------------------------
# NaN                                                                                                                                                                        4986
# Bluetooth, USB                                                                                                                                                              753
# Bluetooth                                                                                                                                                                   665
# On-board computer                                                                                                                                                           662
# ...

# %%
filling_mode(df, "make_model", "body_type", "entertainment_media")

# %%
df.entertainment_media.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Safety Security

# %%
information("safety_security")
# Out:
# column name    :  safety_security
# --------------------------------
# per_of_nulls   :  % 11.23
# num_of_nulls   :  3215
# num_of_uniques :  12549
# --------------------------------
# NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          3215
# ...

# %%
filling_mode(df, "make_model", "body_type", "safety_security")

# %%
df.safety_security.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Extras

# %%
information("extras")
# Out:
# column name    :  extras
# --------------------------------
# per_of_nulls   :  % 17.99
# num_of_nulls   :  5150
# num_of_uniques :  9360
# --------------------------------
# NaN                                                                                                                                                                                                                                                                 5150
# Alloy wheels                                                                                                                                                                                                                                                        3408
# Alloy wheels, Roof rack                                                                                                                                                                                                                                              380
# ...

# %%
filling_mode(df, "make_model", "body_type", "extras")

# %%
df.extras.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Age

# %%
information("age")
# Out:
# column name    :  age
# --------------------------------
# per_of_nulls   :  % 0.01
# num_of_nulls   :  2
# num_of_uniques :  83
# --------------------------------
#  3.0      3667
#  4.0      3492
#  0.0      3086
#  1.0      2870
#  2.0      2473
#  5.0      2426
#  6.0      1486
#  7.0      1237
#  8.0       936
#  9.0       703
#  10.0      655
#  11.0      642
#  12.0      559
#  15.0      492
#  14.0      441
#  13.0      424
#  16.0      395
#  17.0      287
#  18.0      247
#  19.0      211
#  21.0      191
#  20.0      187
#  22.0      160
#  23.0      144
#  24.0       91
#  25.0       81
#  28.0       80
#  27.0       78
#  26.0       71
#  31.0       62
#  30.0       60
#  29.0       55
#  32.0       54
#  56.0       41
#  55.0       34
#  34.0       33
#  57.0       32
#  49.0       29
#  50.0       29
#  54.0       27
#  35.0       26
#  44.0       23
#  36.0       22
#  33.0       20
#  52.0       19
#  51.0       18
#  37.0       18
#  53.0       17
#  43.0       17
# ...

# %%
df.age = df.age.fillna(0.0)

# %% [markdown]
# ## Full Service History

# %%
information("full_service_history")
# Out:
# column name    :  full_service_history
# --------------------------------
# per_of_nulls   :  % 56.11
# num_of_nulls   :  16065
# num_of_uniques :  1
# --------------------------------
# NaN    16065
# Yes    12565
# Name: full_service_history, dtype: int64

# %%
df.loc[df.full_service_history.isnull()]
# Out:
#                    make_model    price  body_type              type  doors  \
# 0         Mercedes-Benz A 160  16950.0   Compact              Used     5.0
# 1       Mercedes-Benz EQE 350  80900.0   Compact    Pre-registered     4.0
# 2      Mercedes-Benz A 45 AMG  69900.0   Compact              Used     5.0
# 3      Mercedes-Benz A 35 AMG  46990.0   Compact              Used     5.0
# 4      Mercedes-Benz A 45 AMG  16800.0   Compact              Used     5.0
# ...                       ...      ...        ...               ...    ...
# 28621               Volvo S90  27190.0     Sedan              Used     4.0
# 28622               Volvo S90  27190.0     Sedan              Used     4.0
# 28624               Volvo S60   4999.0     Sedan              Used     4.0
# 28625               Volvo S90  37600.0     Sedan              Used     4.0
# 28629               Volvo S80   4440.0     Sedan              Used     4.0
#
# ...

# %%
df.full_service_history.value_counts(dropna = False)
# Out:
# NaN    16065
# Yes    12565
# Name: full_service_history, dtype: int64

# %%
df.drop("full_service_history", axis = 1, inplace = True)
#I'm dropping this column for no fillable values and too many nan values.

# %% [markdown]
# ## Upholstery

# %%
information("upholstery")
# Out:
# column name    :  upholstery
# --------------------------------
# per_of_nulls   :  % 35.0
# num_of_nulls   :  10020
# num_of_uniques :  2
# --------------------------------
# NaN        10020
# Cloth       9364
# Leather     9246
# Name: upholstery, dtype: int64

# %%
def fill_forward(df, group_col, col_name):   
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        df.loc[cond, col_name] = df.loc[cond, col_name].fillna(method="ffill").fillna(method="bfill")
    df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")

# %%
fill_forward(df, "make_model", "upholstery")

# %%
df.upholstery.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Previous Owner

# %%
information("previous_owner")
# Out:
# column name    :  previous_owner
# --------------------------------
# per_of_nulls   :  % 51.05
# num_of_nulls   :  14615
# num_of_uniques :  13
# --------------------------------
# NaN     14615
# 1.0      9746
# 2.0      3221
# 3.0       699
# 4.0       184
# 5.0        69
# 6.0        37
# 7.0        22
# 8.0        16
# 9.0        14
# 12.0        3
# 10.0        2
# 14.0        1
# 13.0        1
# Name: previous_owner, dtype: int64

# %%
def fill_single(df, group_col, col_name):
    
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        mode = list(df[cond][col_name].mode())
        if mode != []:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[cond][col_name].mode()[0])
        else:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[col_name].mode()[0])

# %%
fill_single(df, "age", "previous_owner")

# %%
df.previous_owner.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## Co2 Efficiency

# %%
information("co2_efficiency")
# Out:
# column name    :  co2_efficiency
# --------------------------------
# per_of_nulls   :  % 72.74
# num_of_nulls   :  20826
# num_of_uniques :  1
# --------------------------------
# NaN                                                                                           20826
# Calculated on basis of measured CO₂-emissions taking into account the mass of the vehicle.     7804
# Name: co2_efficiency, dtype: int64

# %%
df.drop("co2_efficiency", axis = 1, inplace = True)
#I'm dropping this column for no fillable values and too many nan values.

# %% [markdown]
# ## Average Consumption

# %%
information("avg_consumption")
# Out:
# column name    :  avg_consumption
# --------------------------------
# per_of_nulls   :  % 29.79
# num_of_nulls   :  8530
# num_of_uniques :  145
# --------------------------------
# NaN     8530
# 4.9      756
# 5.0      738
# 5.1      598
# 4.5      593
# 4.7      550
# 5.4      544
# 5.6      543
# 4.8      534
# 4.3      494
# 5.2      487
# 4.6      486
# 5.3      479
# 5.7      475
# 4.2      470
# 3.8      464
# 5.9      452
# 4.1      444
# 5.5      421
# 6.4      410
# 6.3      386
# 6.0      383
# 4.4      378
# 5.8      347
# 4.0      335
# 0.0      314
# 3.6      286
# 7.0      283
# 3.7      277
# 6.5      275
# 3.4      272
# 6.6      258
# 6.9      257
# 6.1      257
# 7.4      257
# 6.2      250
# 7.1      242
# 6.7      235
# 3.9      220
# 6.8      204
# 7.3      199
# 8.4      190
# 7.2      184
# 8.0      179
# 7.6      172
# 8.2      158
# 7.8      158
# 7.7      158
# 3.5      151
# 7.5      140
# 12.0     106
# 12.5     102
# 9.2       95
# 9.0       95
# ...

# %%
df.avg_consumption = df.avg_consumption.fillna((df.city_consumption + df.country_consumption)/2)

# %%
df.avg_consumption.isnull().sum()
# Out:
# 8530

# %%
df.avg_consumption.unique()
# Out:
# array([ nan,  8.4,  7.3,  4.9,  8.2,  6.1,  5.4,  6.9,  6. ,  5.2,  3.9,
#         3.7,  0. ,  3.8,  7.1,  7.6,  5.3,  5.6,  4.7,  4.2,  4.3,  4.1,
#         4.6,  7.2,  4.4,  5.5,  6.6,  6.2,  6.7, 12.4, 11.3,  3.6,  3.5,
#         9.6,  4. ,  5.8,  5.7,  8. ,  7.9,  5. , 99.9,  4.5, 11.4,  7.8,
#         6.8, 13. , 10.1, 13.2,  6.4,  8.6, 12.3, 12.9, 12.5, 15.1,  8.8,
#        11.5,  9.4,  9.5,  9.2, 14. , 11.7, 11.6,  9. ,  8.3, 11.9, 13.5,
#         8.7, 11.1,  4.8, 10.4,  6.3, 10.2,  7.5,  8.9, 10.6,  9.7,  7.7,
#         6.5,  7. ,  9.1, 10. , 13.9,  8.1, 16.7,  5.9, 12.7,  9.9,  9.3,
#        14.1, 10.7,  9.8, 10.9, 12. ,  5.1, 14.9, 13.1, 12.1, 13.4, 10.3,
#        14.2, 16.4, 10.8, 14.3, 10.5, 11.2, 11. ,  7.4,  8.5, 11.8, 16.5,
#        13.8, 15.9, 12.2, 14.4, 12.6, 61. , 14.5,  3.2,  3.3,  3.4,  3.1,
#         3. , 57. , 16. ,  1.4,  0.5,  1.1,  2.8,  2.2, 15.6,  0.8, 56. ,
#         2.9, 13.6,  1. , 44. , 15.5,  0.7, 93. , 12.8, 16.8, 15. , 14.7,
# ...

# %%
df.loc[df.fuel_type == "Hybrit", "avg_consumption"]
# Out:
# 1       NaN
# 93      NaN
# 94      NaN
# 108     NaN
# 1213    NaN
# 1226    NaN
# 1271    NaN
# 1273    NaN
# 1281    NaN
# 1283    NaN
# 1303    NaN
# 1304    NaN
# 1307    NaN
# 1326    NaN
# 1331    NaN
# 1341    NaN
# 1350    NaN
# 1361    NaN
# 1364    NaN
# 1369    NaN
# 1400    NaN
# 1416    NaN
# 1425    NaN
# 1427    NaN
# 1436    NaN
# 1447    NaN
# 1458    NaN
# 1513    NaN
# 1575    NaN
# 1628    NaN
# 1641    NaN
# 1777    NaN
# 1798    NaN
# 1998    NaN
# 2000    NaN
# 2004    NaN
# 2015    NaN
# 2045    NaN
# 2082    NaN
# 2084    NaN
# 2086    NaN
# 2099    NaN
# 2130    NaN
# 2144    NaN
# 2156    NaN
# 2161    NaN
# 2166    NaN
# 2182    NaN
# 2192    NaN
# 2199    NaN
# 2230    NaN
# 2246    NaN
# 2255    NaN
# 2272    NaN
# 2276    NaN
# 2278    NaN
# 2301    NaN
# 2312    NaN
# 2317    NaN
# 2322    NaN
# 2328    NaN
# 2331    NaN
# 2355    NaN
# 2356    NaN
# 2360    NaN
# 2372    NaN
# 2713    NaN
# 3663    NaN
# 4810    NaN
# 4819    NaN
# 4823    NaN
# ...

# %%
df.loc[df.avg_consumption > 17.0]
# Out:
#                 make_model    price           body_type              type  \
# 265    Mercedes-Benz A 180  32750.0            Compact              Used
# 1771   Mercedes-Benz E 200  22480.0      Station wagon              Used
# 6580        Renault Megane  17488.0      Station wagon              Used
# 18546         Toyota Yaris  17490.0              Sedan              Used
# 18798       Nissan Qashqai  21995.0            Compact              Used
# 18799       Nissan Qashqai  19595.0            Compact              Used
# 19904       Nissan Qashqai  15400.0   Off-Road/Pick-up              Used
# 20995           Ford Focus  16595.0            Compact              Used
# 21012           Ford Focus  16900.0            Compact              Used
# 23004           Ford Focus  21990.0              Sedan              Used
# 23974         Hyundai KONA  22999.0   Off-Road/Pick-up     Demonstration
# 24144         Hyundai KONA  22999.0   Off-Road/Pick-up    Pre-registered
#
# ...

# %%
df.loc[(df.avg_consumption < 3.5) & (df.avg_consumption != 0) ]
# Out:
#                make_model     price           body_type              type  \
# 2457           Opel Corsa   15990.0            Compact              Used
# 2496           Opel Corsa    8990.0            Compact              Used
# 2562           Opel Corsa   20500.0            Compact              Used
# 2689           Opel Corsa   16449.0            Compact              Used
# 3569           Opel Corsa   10800.0              Coupe              Used
# 4009           Opel Astra   11490.0      Station wagon              Used
# 4051           Opel Astra   13290.0      Station wagon              Used
# 4142           Opel Astra   16989.0      Station wagon              Used
# 4161           Opel Astra   16989.0      Station wagon              Used
# 4281           Opel Astra   11950.0      Station wagon              Used
# 4346           Opel Astra   12385.0      Station wagon              Used
# 4415           Opel Corsa   10999.0              Sedan              Used
# ...

# %%
df["avg_consumption"].replace([99.9, 61.0, 57.0, 56.0, 44.0, 93.0, 53.0], np.nan, inplace=True)

# %%
df.avg_consumption.isnull().sum()
# Out:
# 8542

# %%
def fill_median(df, group_col1, group_col2,col_name):
    df[col_name].fillna(df.groupby([group_col1, group_col2])[col_name].transform("median"), inplace = True)
    df[col_name].fillna(df.groupby(group_col1)[col_name].transform("median"), inplace = True)
    df[col_name].fillna(df[col_name].median(), inplace = True)

# %%
fill_median(df, "make_model", "fuel_type", "avg_consumption")

# %%
df.avg_consumption.isnull().sum()
# Out:
# 0

# %% [markdown]
# ## City Consumption

# %%
df.drop("city_consumption", axis = 1, inplace = True)

# %% [markdown]
# ## Country Consumption

# %%
df.drop("country_consumption", axis = 1, inplace = True)

# %%
df.isnull().sum()
# Out:
# make_model             0
# price                  0
# body_type              0
# type                   0
# doors                  0
# mileage                0
# first_registration     0
# gearbox                0
# fuel_type              0
# seller                 0
# seats                  0
# power                  0
# engine_size            0
# gears                  0
# co2_emissions          0
# drivetrain             0
# cylinders              0
# comfort_convenience    0
# entertainment_media    0
# safety_security        0
# extras                 0
# upholstery             0
# previous_owner         0
# avg_consumption        0
# age                    0
# dtype: int64

# %%
df.to_csv("filled_data.csv", index=False)

# %% [markdown]
# # PART- 3 `( Handling With Outliers )`

# %% [markdown]
# # Final Step (Checking final situation of data via graphs)

# %% [markdown]
# ## Export dataframe to csv file (without dummy)

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)

# %% [markdown]
# # Dummy Operation

# %% [markdown]
# ## Export dataframe to csv file (dummy)

# %%
df_dummied.to_csv("final_scout_dummy.csv", index=False)
